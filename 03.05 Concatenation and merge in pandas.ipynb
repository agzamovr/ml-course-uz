# %% [markdown]
# # Объединение нескольких наборов данных
# Pandas включает в себя несколько способов для объединения различных наборов данных. Данные могут быть объединены как посредством логики теории множеств так и реляционной алгебры, которая используется в реляционных базах данных.
#
# ## [Конкатенация](https://pandas.pydata.org/pandas-docs/stable/merging.html#concatenating-objects)
# С помощью метода `pd.concat` можно сконкатенировать несколько наборов данных в один единый набор. В результате конкатенации данные складываются друг над другом или бок о бок. При этом данные выравниваются либо по колонкам либо по индексам.
#
# Для начала загрузим вспомоготальный модуль, который поможет наглядно отобразить наборы данных и результат их объединения

# %%
import numpy as np
import pandas as pd

# %%
# %run code/util.py

# %% [markdown]
# Теперь создадим три набора данных, которые будем затем объединять в один набор

# %%
countries = ['Afghanistan', 'Kazakhstan', 'Kyrgyzstan', 'Tajikistan', 'Turkmenistan', 'Uzbekistan']
area = [652864, 2724900, 199951, 143100, 491210, 448978]
population = [34656032, 17987736, 6019480, 8734951, 5662544, 32979000]
gdp = [21, 156.189, 7.061, 27.802, 42.355, 68.324]
gini = [29, 26.4, 27.4, 30.8, 40.8, 36.7]

df1 = pd.DataFrame(data={'country': countries[:2], 'area': area[:2], 'population': population[:2], 
                         'gdp': gdp[:2], 'gini': gini[:2]}, index=[1, 2])
df2 = pd.DataFrame(data={'country': countries[2:4], 'area': area[2:4], 'population': population[2:4], 
                         'gdp': gdp[2:4], 'gini': gini[2:4]}, index=[3, 4])
df3 = pd.DataFrame(data={'country': countries[4:], 'area': area[4:], 'population': population[4:], 
                         'gdp': gdp[4:], 'gini': gini[4:]}, index=[5, 6])

frames = [df1, df2, df3]
result = pd.concat(frames)
display_stacked(frames, result)
# Out:
# <div style="float: left; padding-right: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Если в метод `pd.concat` передать параметр `keys` со списком значений для каждого набора, то в результирующий набор данных получить иерархический индекс со значениями `keys` в качестве самого верхнего уровня

# %%
result = pd.concat(frames, keys=['first', 'second', 'third'])
display_stacked(frames, result)
# Out:
# <div style="float: left; padding-right: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">first</th>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">second</th>
#       <th>3</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">third</th>
#       <th>5</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Можно выбрать нужный набор по этим ключам

# %%
result.loc['second']
# Out:
#      area     country     gdp  gini  population
# 3  199951  Kyrgyzstan   7.061  27.4     6019480
# 4  143100  Tajikistan  27.802  30.8     8734951

# %% [markdown]
# Для горизонтальной конкатенации, когда данные объединяются бок о бок, нужно передать параметр `axis` со значением 1. Если при вертикальной конкатенации данные выравнивались по колонкам, то при горизонтальной конкатенации они выравниваются по индексам. Поэтому в нашем случае, чтобы в результирующем наборе были две строки, необходимо установить одинаковые индексы для каждого набора

# %%
df1.index = [1, 2]
df2.index = [1, 2]
df3.index = [1, 2]
result = pd.concat(frames, axis=1)
display_horizontal(frames, result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Все значения оси (колонки или индексы), по которой идет конкатенация, будут оставлены в результирующем наборе данных, даже если эти значения дублируются. Например, в предыдущем примере название каждой колонки встречается по три раза. При этом для другой оси, по которой не идет конкатенация, можно указать как поступить, если не все значения этой оси совпадают во всех наборах. Например, если в предыдущем примере у каждого набора были бы разные значения индексов, то их не получилось бы выровнить. С помощью параметра `join` можно указать как поступить в таком случае. По умолчанию параметр имеет значение `outer`, что соответствует сохранению всех значений

# %%
df1.index = [1, 2]
df2.index = [2, 3]
df3.index = [3, 4]
result = pd.concat(frames, axis=1, join='outer')
display_horizontal(frames, result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864.0</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900.0</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736.0</td>
#       <td>199951.0</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>143100.0</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951.0</td>
#       <td>491210.0</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>448978.0</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# В итоге данные сложились как лесенькой и с пустыми значениями в строках, в которых не бло значений во всех наборах данных. Если же передать в параметр `join` значение `inner`, то в итоге останутся лишь те записи, значения индексов которых есть во всех наборах данных

# %%
df1.index = [1, 2]
df2.index = [1, 3]
df3.index = [1, 4]
result = pd.concat(frames, axis=1, join='inner')
display_horizontal(frames, result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.0</td>
#       <td>29.0</td>
#       <td>34656032</td>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# И наконец можно передать отдельный индекс в параметр `join_axes`, который будет использован при конкатенации. Все значения, индексы которых есть в переданном в `join_axes` индексе, будут оставлены в результирующем наборе данных. В качестве такого индекса можно использовать индексы нескольких объединяемых наборов данных. В результате все значения выбранных наборов будут оставлены, а из остальных наборов останутся лишь те значения, индексы которых есть в выбранном индексе. В следующем примере в `join_axes` передается объединение индексов первых двух наборов данных `df1.index | df2.index`. В результате все значения этих двух наборов остаются, а запись с индексом 4 в третьем наборе исключается из результата

# %%
df1.index = [1, 2]
df2.index = [1, 3]
df3.index = [2, 4]
result = pd.concat(frames, axis=1, join_axes=[df1.index | df2.index])
display_horizontal(frames, result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>652864.0</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#       <td>34656032.0</td>
#       <td>199951.0</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#       <td>6019480.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900.0</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#       <td>17987736.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>491210.0</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#       <td>5662544.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>143100.0</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#       <td>8734951.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## [Слияние в стиле реляционных СУБД](https://pandas.pydata.org/pandas-docs/stable/merging.html#database-style-dataframe-joining-merging)
# Pandas включает в себя возможность для слияния (merge) данных в стиле SQL (соответствует оператору `join`). Для этого используется метод `pd.merge`. Стоит отметить, что слияние в pandas реализовано очень эффективно и в некоторых случаях может выполняться на порядок быстрее, чем в аналогичных библиотеках (например, в R).
#
# SQL включает в себя несколько типов объединения данных
# 1. Один к одному - одна запись в таблице соответствует одной записи в другой таблице (one-to-one)
# 2. Один ко многим - одна запись в таблице соответствует многим записям в другой таблице (one-to-many)
# 3. Многое ко многим - множество записей в таблице соответствуют множеству записей в другой таблице (many-to-many)
#
# Если название колонок, по которым нужно объеденить два набора данных, совпадают, то можно их объеденить, указав ключ в параметре `on`. В следующем примере строки в двух наборах данных объединяются по ключу `country` и они совпадают один к одному

# %%
df_left = pd.DataFrame(data={'country': countries, 'area': area})
df_right = pd.DataFrame(data={'country': countries, 'gdp': gdp, 'gini': gini})

result = pd.merge(df_left, df_right, on='country')
display_horizontal([df_left, df_right], result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>gdp</th>
#       <th>gini</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>29.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>26.4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>27.4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>30.8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>40.8</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>36.7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Точно так же можно объединить наборы данных, строки которых соотносятся как один ко многим. В следующем примере используется данные, которые содержат внешний долг страны за 2015 и 2016 годы (согласно базе Всемирного Банка)

# %%
external_debt_2015_2016 = [153381212000, 14854025000, 
                           163757713000, 16282526000]
year = [2015] * 2 + [2016] * 2
key = ['Kazakhstan', 'Uzbekistan'] * 2

df_debt = pd.DataFrame(data={'country': key, 'year': year, 
                             'external_debt': external_debt_2015_2016})
df_debt
# Out:
#       country  external_debt  year
# 0  Kazakhstan   153381212000  2015
# 1  Uzbekistan    14854025000  2015
# 2  Kazakhstan   163757713000  2016
# 3  Uzbekistan    16282526000  2016

# %% [markdown]
# При слиянии данные из левого набора продублируются, так как каждой строке соответствуют две строки из правого набора. Страны, данные по которым отсутствуют в правом наборе, будут исключены из результата

# %%
result = pd.merge(df_left, df_debt, on='country')
display_horizontal([df_left, df_debt], result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>external_debt</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kazakhstan</td>
#       <td>153381212000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Uzbekistan</td>
#       <td>14854025000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kazakhstan</td>
#       <td>163757713000</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Uzbekistan</td>
#       <td>16282526000</td>
#       <td>2016</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>external_debt</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>153381212000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>163757713000</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>14854025000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>16282526000</td>
#       <td>2016</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Мы можем оставить все данные из левого набора указав параметр `how=left` (по умолчанию `how=inner`). При этом внешний долг в тех строках, для которых отсутствуют соответствующие строки в правом наборе, будут иметь пустые значения

# %%
result = pd.merge(df_left, df_debt, on='country', how='left')
display_horizontal([df_left, df_debt], result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>external_debt</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kazakhstan</td>
#       <td>153381212000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Uzbekistan</td>
#       <td>14854025000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kazakhstan</td>
#       <td>163757713000</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Uzbekistan</td>
#       <td>16282526000</td>
#       <td>2016</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>country</th>
#       <th>external_debt</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>1.533812e+11</td>
#       <td>2015.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>1.637577e+11</td>
#       <td>2016.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>1.485402e+10</td>
#       <td>2015.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>1.628253e+10</td>
#       <td>2016.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# При слиянии можно указать более чем одну колонку, по которым нужно объединить наборы. Создадим еще один набор с данными по численности населения за 2015 и 2016 год

# %%
population_2015_2016 = [17544126, 31298900, 
                        17797032, 31848200]
df_pop = pd.DataFrame(data={'country': key, 'year': year, 
                            'population': population_2015_2016})
df_pop
# Out:
#       country  population  year
# 0  Kazakhstan    17544126  2015
# 1  Uzbekistan    31298900  2015
# 2  Kazakhstan    17797032  2016
# 3  Uzbekistan    31848200  2016

# %% [markdown]
# Теперь можем объединить данные по внешнему долгу и численности населения связав их по двум ключам `country` и `year`

# %%
df_debt_pop = pd.merge(df_debt, df_pop, on=['country', 'year'])
display_horizontal([df_debt, df_pop], df_debt_pop)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>external_debt</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kazakhstan</td>
#       <td>153381212000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Uzbekistan</td>
#       <td>14854025000</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kazakhstan</td>
#       <td>163757713000</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Uzbekistan</td>
#       <td>16282526000</td>
#       <td>2016</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>population</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kazakhstan</td>
#       <td>17544126</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Uzbekistan</td>
#       <td>31298900</td>
#       <td>2015</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kazakhstan</td>
#       <td>17797032</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Uzbekistan</td>
#       <td>31848200</td>
#       <td>2016</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>external_debt</th>
#       <th>year</th>
#       <th>population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kazakhstan</td>
#       <td>153381212000</td>
#       <td>2015</td>
#       <td>17544126</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Uzbekistan</td>
#       <td>14854025000</td>
#       <td>2015</td>
#       <td>31298900</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kazakhstan</td>
#       <td>163757713000</td>
#       <td>2016</td>
#       <td>17797032</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Uzbekistan</td>
#       <td>16282526000</td>
#       <td>2016</td>
#       <td>31848200</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Если названия колонок в двух наборах не совпадают, то можно использовать параметры `left_on` и `right_on` для указания колонок в каждом наборе по отдельности. При этом обе колонки останутся в результирующем наборе

# %%
df_left = pd.DataFrame(data={'left_key': countries, 'area': area})
df_right = pd.DataFrame(data={'right_key': countries, 'gdp': gdp})

result = pd.merge(df_left, df_right, left_on='left_key', right_on='right_key')
display_horizontal([df_left, df_right], result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>left_key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gdp</th>
#       <th>right_key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>21.000</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>156.189</td>
#       <td>Kazakhstan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.061</td>
#       <td>Kyrgyzstan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>27.802</td>
#       <td>Tajikistan</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>42.355</td>
#       <td>Turkmenistan</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>68.324</td>
#       <td>Uzbekistan</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>left_key</th>
#       <th>gdp</th>
#       <th>right_key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>652864</td>
#       <td>Afghanistan</td>
#       <td>21.000</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2724900</td>
#       <td>Kazakhstan</td>
#       <td>156.189</td>
#       <td>Kazakhstan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>199951</td>
#       <td>Kyrgyzstan</td>
#       <td>7.061</td>
#       <td>Kyrgyzstan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>143100</td>
#       <td>Tajikistan</td>
#       <td>27.802</td>
#       <td>Tajikistan</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>491210</td>
#       <td>Turkmenistan</td>
#       <td>42.355</td>
#       <td>Turkmenistan</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>448978</td>
#       <td>Uzbekistan</td>
#       <td>68.324</td>
#       <td>Uzbekistan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Мы можем передать суффиксы, чтобы в объединенном наборе различать колонки с одинаковым названием. Кроме того, данные могут быть объединены по индексу. В следующем примере демонстрируются обе этих возможностей

# %%
df_left = pd.DataFrame(data={'param_name': ['area', 'population'], 
                             'value': [area[-1], population[-1]]})
df_right = pd.DataFrame(data={'param_name': ['gdp', 'gini'], 
                             'value': [gdp[-1], gini[-1]]})
result = pd.merge(df_left, df_right, left_index=True, right_index=True, suffixes=('_left', '_right'))
display_horizontal([df_left, df_right], result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>param_name</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>area</td>
#       <td>448978</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>population</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>param_name</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gdp</td>
#       <td>68.324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>gini</td>
#       <td>36.700</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>param_name_left</th>
#       <th>value_left</th>
#       <th>param_name_right</th>
#       <th>value_right</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>area</td>
#       <td>448978</td>
#       <td>gdp</td>
#       <td>68.324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>population</td>
#       <td>32979000</td>
#       <td>gini</td>
#       <td>36.700</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Если данные объединяются по индексу, как в предыдущем примере, то можно использовать метод [`join`](https://pandas.pydata.org/pandas-docs/stable/merging.html#joining-on-index), который является оберткой метода `merge` и предоставляет несколько сокращенный способ написания кода

# %%
result = df_left.join(df_right, lsuffix='_left', rsuffix='_right')
display_horizontal([df_left, df_right], result)
# Out:
# <div padding-bottom: 20px;">
#     <p style='font-family:"Courier New", Courier, monospace'><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>param_name</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>area</td>
#       <td>448978</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>population</td>
#       <td>32979000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>param_name</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gdp</td>
#       <td>68.324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>gini</td>
#       <td>36.700</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></p>
#     </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>param_name_left</th>
#       <th>value_left</th>
#       <th>param_name_right</th>
#       <th>value_right</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>area</td>
#       <td>448978</td>
#       <td>gdp</td>
#       <td>68.324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>population</td>
#       <td>32979000</td>
#       <td>gini</td>
#       <td>36.700</td>
#     </tr>
#   </tbody>
# </table>
